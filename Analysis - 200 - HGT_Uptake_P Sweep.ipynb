# %%
ls

# %%
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy  
import scikits.bootstrap as bootstrap
from scipy import stats
# %matplotlib inline

pd.__version__
# Out:
# u'0.17.1'

# %%
cat raw_data/P_0.1/hgtbonus/P_0.1_hgtbonus_200001/data_hgtbonus/average.dat | head
# Out:
# # Avida Average Data
# # Sat Jan  2 14:16:59 2016
# #  1: Update
# #  2: Merit
# #  3: Gestation Time
# #  4: Fitness
# #  5: Repro Rate?
# #  6: (deprecated) Size
# #  7: Copied Size
# #  8: Executed Size
# cat: write error: Broken pipe

# %%
import sys
sys.path.append("../research_scripts/")
# %run ../research_scripts/quickplot.py --help
# Out:
# Usage: quickplot.py [options] outfile [input_file1 column1 "directory_glob1" name1 .. input_fileN columnN "directory_globN" nameN]
#
#
#
# Options:
#   -h, --help            show this help message and exit
#   -v, --verbose         print extra messages to stdout
#   -d, --debug_messages  print debug messages to stdout
#   --plotonly            Skip the aggregation step, and plot only, using
#                         existing data files.
#   -t TITLE, --title=TITLE
#                         set a different title than outfile (default)
#   -x XLABEL, --xlabel=XLABEL
#                         X-axis Label
#   -y YLABEL, --ylabel=YLABEL
#                         Y-axis Label
#   --data_members=MEMBER_COUNT
#                         Number of Components from a given data source
#                         (treatment)
#   --xtick_multiplier=XTICK_MULTIPLIER
#                         X-axis Tick Multipliers
#   --ylog                Y-axis logarithmic scale
# ...

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--ylog --title "Fitness at Different Probabilities for HGT Uptake" \
--xlabel "Updates" --ylabel "Fitness" --xtick_multiplier 100 \
fitness \
average.dat 4 \"./raw_data/P_0/control/*/data*/\" control \
average.dat 4 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0 \
average.dat 4 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001 \
average.dat 4 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01 \
average.dat 4 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1 \
average.dat 4 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5 \
average.dat 4 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1 

from IPython.display import Image
Image(filename='fitness.png')
# Out:
# Aggregating control
# Aggregating P_0
# Aggregating P_0.001
# Aggregating P_0.01
# Aggregating P_0.1
# Aggregating P_0.5
# Aggregating P_1
#
# Plotting fitness

# %%
cat raw_data/P_0.1/hgtbonus/P_0.1_hgtbonus_200001/data_hgtbonus/hgt.dat | head -n 15
# Out:
# # Horizontal gene transfer statistics
# # Sat Jan  2 14:16:59 2016
# #  1: Update [update]
# #  2: Total count of metabolized genome fragments [metcount]
# #  3: Total size of metabolized genome fragments [metsize]
# #  4: Total count of insertion events [inscount]
# #  5: Total size of insertion events [inssize]
# #  6: Simple count of insertion events [inscount] DEBUG-RCK
# #  7: Simple count of uptake events [inscount] DEBUG-RCK
# #  8: Simple count of recombination events [inscount] DEBUG-RCK
# #  9: Simple count of bonus events [inscount] DEBUG-RCK
#
# 0 0 0 0 0 0 0 0 0
# 100 0 0 0 0 0 0 0 0
# 200 0 0 0 0 0 163 15 148

# %%
# %run ../research_scripts/quickplot.py --samples 1000 \
--title "HGT Recombination Rates at Different Probabilities for HGT Uptake Recombination" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_recombination_rates \
hgt.dat 8 \"./raw_data/P_0/control/*/data*/\" control \
hgt.dat 8 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0 \
hgt.dat 8 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001 \
hgt.dat 8 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01 \
hgt.dat 8 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1 \
hgt.dat 8 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5 \
hgt.dat 8 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1 

from IPython.display import Image
Image(filename='hgt_recombination_rates.png')
# Out:
# Aggregating control
# Aggregating P_0
# Aggregating P_0.001
# Aggregating P_0.01
# Aggregating P_0.1
# Aggregating P_0.5
# Aggregating P_1
#
# Plotting hgt_recombination_rates

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes at Different Probabilities for HGT Uptake" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_uptake \
hgt.dat 7 \"./raw_data/P_0/control/*/data*/\" control \
hgt.dat 7 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0 \
hgt.dat 7 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001 \
hgt.dat 7 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01 \
hgt.dat 7 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1 \
hgt.dat 7 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5 \
hgt.dat 7 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1 

from IPython.display import Image
Image(filename='hgt_uptake.png')
# Out:
# Aggregating control
# Aggregating P_0
# Aggregating P_0.001
# Aggregating P_0.01
# Aggregating P_0.1
# Aggregating P_0.5
# Aggregating P_1
#
# Plotting hgt_uptake

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Uptake_P: 0.001)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_uptake_nobonus_0.001 \
hgt.dat 7 \"./raw_data/P_0.001/control/*/data*/\" control \
hgt.dat 7 \"./raw_data/P_0.001/bonus/*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.001/hgtbonus/*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.001/hgt/*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='hgt_uptake_nobonus_0.001.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting hgt_uptake_nobonus_0.001

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Uptake_P: 0.01)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_uptake_nobonus_0.01 \
hgt.dat 7 \"./raw_data/P_0.01/control/*/data*/\" control \
hgt.dat 7 \"./raw_data/P_0.01/bonus/*/data*/\" noHGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.01/hgtbonus/*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.01/hgt/*/data*/\" HGT+NoBonus \


from IPython.display import Image
Image(filename='hgt_uptake_nobonus_0.01.png')
# Out:
# Aggregating control
# Aggregating noHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting hgt_uptake_nobonus_0.01

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Uptake_P: 0.1)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_uptake_nobonus_0.1 \
hgt.dat 7 \"./raw_data/P_0.1/control/*/data*/\" control_nop \
hgt.dat 7 \"./raw_data/P_0.1/bonus/*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.1/hgtbonus/*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.1/hgt/*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='hgt_uptake_nobonus_0.1.png')
# Out:
# Aggregating control_nop
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting hgt_uptake_nobonus_0.1

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Uptake_P: 0.25)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
hgt_uptake_nobonus_0.25 \
hgt.dat 7 \"./raw_data/P_0.25/control/*/data*/\" control_nop \
hgt.dat 7 \"./raw_data/P_0.25/bonus/*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.25/hgtbonus/*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/P_0.25/hgt/*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='hgt_uptake_nobonus_0.25.png')
# Out:
# Aggregating control_nop
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting hgt_uptake_nobonus_0.25

# %%
cat raw_data/P_0.1/hgtbonus/P_0.1_hgtbonus_200001/data_hgtbonus/average.dat | head -n 20
# Out:
# # Avida Average Data
# # Sat Jan  2 14:16:59 2016
# #  1: Update
# #  2: Merit
# #  3: Gestation Time
# #  4: Fitness
# #  5: Repro Rate?
# #  6: (deprecated) Size
# #  7: Copied Size
# #  8: Executed Size
# #  9: (deprecated) Abundance
# # 10: Proportion of organisms that gave birth in this update
# # 11: Proportion of Breed True Organisms
# # 12: (deprecated) Genotype Depth
# # 13: Generation
# # 14: Neutral Metric
# # 15: Lineage Label
# # 16: True Replication Rate (based on births/update, time-averaged)
#
# 0 97 389 0 0 0 100 97 0 1 1 0 0 0 0 0
# cat: write error: Broken pipe

# %%
# %run ../research_scripts/quickplot.py --samples 1000 \
--title "Genome Length at Different Probabilities for HGT Uptake" \
--xlabel "Updates" --ylabel "Fitness" --xtick_multiplier 100 \
copied_size \
average.dat 7 \"./raw_data/P_0/control/*/data*/\" control \
average.dat 7 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0 \
average.dat 7 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001 \
average.dat 7 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01 \
average.dat 7 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1 \
average.dat 7 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5 \
average.dat 7 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1 

from IPython.display import Image
Image(filename='copied_size.png')
# Out:
# Aggregating control
# Aggregating P_0
# Aggregating P_0.001
# Aggregating P_0.01
# Aggregating P_0.1
# Aggregating P_0.5
# Aggregating P_1
#
# Plotting copied_size

# %%
# %run ../research_scripts/quickplot.py --samples 1000 \
--title "Genome Exec Length at Different Probabilities for HGT Uptake" \
--xlabel "Updates" --ylabel "Fitness" --xtick_multiplier 100 \
exec_size \
average.dat 8 \"./raw_data/P_0/control/*/data*/\" control \
average.dat 8 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0 \
average.dat 8 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001 \
average.dat 8 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01 \
average.dat 8 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1 \
average.dat 8 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5 \
average.dat 8 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1 

from IPython.display import Image
Image(filename='exec_size.png')
# Out:
# Aggregating control
# Aggregating P_0
# Aggregating P_0.001
# Aggregating P_0.01
# Aggregating P_0.1
# Aggregating P_0.5
# Aggregating P_1
#
# Plotting exec_size

# %%
# %run ../research_scripts/quickplot.py --samples 1000 \
--title "Genome Exec Length at Different Probabilities for HGT Uptake" \
--xlabel "Updates" --ylabel "Fitness" --xtick_multiplier 100 \
--data_members 2 \
copied_and_exec_size \
average.dat 7 \"./raw_data/P_0/control/*/data*/\" control_c \
average.dat 8 \"./raw_data/P_0/control/*/data*/\" control_e \
average.dat 7 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0_c \
average.dat 8 \"./raw_data/P_0/hgtbonus/*/data*/\" P_0_e \
average.dat 7 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001_c \
average.dat 8 \"./raw_data/P_0.001/hgtbonus/*/data*/\" P_0.001_e \
average.dat 7 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01_c \
average.dat 8 \"./raw_data/P_0.01/hgtbonus/*/data*/\" P_0.01_e \
average.dat 7 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1_c \
average.dat 8 \"./raw_data/P_0.1/hgtbonus/*/data*/\" P_0.1_e \
average.dat 7 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5_c \
average.dat 8 \"./raw_data/P_0.5/hgtbonus/*/data*/\" P_0.5_e \
average.dat 7 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1_c \
average.dat 8 \"./raw_data/P_1/hgtbonus/*/data*/\" P_1_e 

from IPython.display import Image
Image(filename='copied_and_exec_size.png')
# Out:
# Aggregating control_c
# Aggregating control_e
# Aggregating P_0_c
# Aggregating P_0_e
# Aggregating P_0.001_c
# Aggregating P_0.001_e
# Aggregating P_0.01_c
# Aggregating P_0.01_e
# Aggregating P_0.1_c
# Aggregating P_0.1_e
# Aggregating P_0.5_c
# Aggregating P_0.5_e
# Aggregating P_1_c
# Aggregating P_1_e
#
# Plotting copied_and_exec_size
