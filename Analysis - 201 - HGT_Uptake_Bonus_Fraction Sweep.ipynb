# %%
ls raw_data/201_HGT_Bonus_Sweep/
# Out:
# Bonus_0.1_bonus_200101/     Bonus_2_bonus_200101/
# Bonus_0.1_bonus_200102/     Bonus_2_bonus_200102/
# Bonus_0.1_bonus_200103/     Bonus_2_bonus_200103/
# Bonus_0.1_bonus_200104/     Bonus_2_bonus_200104/
# Bonus_0.1_bonus_200105/     Bonus_2_bonus_200105/
# Bonus_0.1_bonus_200106/     Bonus_2_bonus_200106/
# Bonus_0.1_bonus_200107/     Bonus_2_bonus_200107/
# Bonus_0.1_bonus_200108/     Bonus_2_bonus_200108/
# Bonus_0.1_bonus_200109/     Bonus_2_bonus_200109/
# Bonus_0.1_bonus_200110/     Bonus_2_bonus_200110/
# Bonus_0.1_bonus_200111/     Bonus_2_bonus_200111/
# Bonus_0.1_bonus_200112/     Bonus_2_bonus_200112/
# Bonus_0.1_bonus_200113/     Bonus_2_bonus_200113/
# Bonus_0.1_bonus_200114/     Bonus_2_bonus_200114/
# Bonus_0.1_bonus_200115/     Bonus_2_bonus_200115/
# Bonus_0.1_bonus_200116/     Bonus_2_bonus_200116/
# Bonus_0.1_bonus_200117/     Bonus_2_bonus_200117/
# Bonus_0.1_bonus_200118/     Bonus_2_bonus_200118/
# Bonus_0.1_bonus_200119/     Bonus_2_bonus_200119/
# ...

# %%
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy  
import scikits.bootstrap as bootstrap
from scipy import stats
# %matplotlib inline

pd.__version__
# Out:
# u'0.17.1'

# %%
cat raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_hgtbonus_200101/data/average.dat | head
# Out:
# # Avida Average Data
# # Mon Jan 11 17:32:36 2016
# #  1: Update
# #  2: Merit
# #  3: Gestation Time
# #  4: Fitness
# #  5: Repro Rate?
# #  6: (deprecated) Size
# #  7: Copied Size
# #  8: Executed Size
# cat: write error: Broken pipe

# %%
import sys
sys.path.append("../research_scripts/")
# %run ../research_scripts/quickplot.py --help
# Out:
# Usage: quickplot.py [options] outfile [input_file1 column1 "directory_glob1" name1 .. input_fileN columnN "directory_globN" nameN]
#
#
#
# Options:
#   -h, --help            show this help message and exit
#   -v, --verbose         print extra messages to stdout
#   -d, --debug_messages  print debug messages to stdout
#   --plotonly            Skip the aggregation step, and plot only, using
#                         existing data files.
#   -t TITLE, --title=TITLE
#                         set a different title than outfile (default)
#   -x XLABEL, --xlabel=XLABEL
#                         X-axis Label
#   -y YLABEL, --ylabel=YLABEL
#                         Y-axis Label
#   --data_members=MEMBER_COUNT
#                         Number of Components from a given data source
#                         (treatment)
#   --xtick_multiplier=XTICK_MULTIPLIER
#                         X-axis Tick Multipliers
#   --ylog                Y-axis logarithmic scale
# ...

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--ylog --title "Fitness at Different Levels of Bonus" \
--xlabel "Updates" --ylabel "Fitness" --xtick_multiplier 100 \
bonus_fitness \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_hgtbonus_*/data*/\" B_0.1 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_hgtbonus_*/data*/\" B_0.5 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgtbonus_*/data*/\" B_1 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgtbonus_*/data*/\" B_2 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgtbonus_*/data*/\" B_4 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgtbonus_*/data*/\" B_8 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgtbonus_*/data*/\" B_16 \
average.dat 4 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgtbonus_*/data*/\" B_32 

from IPython.display import Image
Image(filename='bonus_fitness.png')
# Out:
# Aggregating control
# Aggregating B_0.1
# Aggregating B_0.5
# Aggregating B_1
# Aggregating B_2
# Aggregating B_4
# Aggregating B_8
# Aggregating B_16
# Aggregating B_32
#
# Plotting bonus_fitness

# %%
cat raw_data/P_0.1/hgtbonus/P_0.1_hgtbonus_200001/data_hgtbonus/hgt.dat | head -n 15
# Out:
# # Horizontal gene transfer statistics
# # Sat Jan  2 14:16:59 2016
# #  1: Update [update]
# #  2: Total count of metabolized genome fragments [metcount]
# #  3: Total size of metabolized genome fragments [metsize]
# #  4: Total count of insertion events [inscount]
# #  5: Total size of insertion events [inssize]
# #  6: Simple count of insertion events [inscount] DEBUG-RCK
# #  7: Simple count of uptake events [inscount] DEBUG-RCK
# #  8: Simple count of recombination events [inscount] DEBUG-RCK
# #  9: Simple count of bonus events [inscount] DEBUG-RCK
#
# 0 0 0 0 0 0 0 0 0
# 100 0 0 0 0 0 0 0 0
# 200 0 0 0 0 0 163 15 148

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Recombination Rate at Different Bonus Levels - HGT + Bonus" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
bonus_hgt_recombination_rate \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgtbonus_*/data*/\" B_1 \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgtbonus_*/data*/\" B_2 \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgtbonus_*/data*/\" B_4 \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgtbonus_*/data*/\" B_8 \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgtbonus_*/data*/\" B_16 \
hgt.dat 8 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgtbonus_*/data*/\" B_32 

from IPython.display import Image
Image(filename='bonus_hgt_recombination_rate.png')
# Out:
# Aggregating control
# Aggregating B_1
# Aggregating B_2
# Aggregating B_4
# Aggregating B_8
# Aggregating B_16
# Aggregating B_32
#
# Plotting bonus_hgt_recombination_rate

# %%
# %run ../research_scripts/quickplot.py --samples 1000 \
--title "Genome Size at Different Bonus Levels - HGT + Bonus" \
--xlabel "Updates" --ylabel "Copied Genome Size" --xtick_multiplier 100 \
bonus_hgt_copiedgenomesize \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgtbonus_*/data*/\" B_1 \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgtbonus_*/data*/\" B_2 \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgtbonus_*/data*/\" B_4 \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgtbonus_*/data*/\" B_8 \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgtbonus_*/data*/\" B_16 \
average.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgtbonus_*/data*/\" B_32 

from IPython.display import Image
Image(filename='bonus_hgt_copiedgenomesize.png')
# Out:
# Aggregating control
# Aggregating B_1
# Aggregating B_2
# Aggregating B_4
# Aggregating B_8
# Aggregating B_16
# Aggregating B_32
#
# Plotting bonus_hgt_copiedgenomesize

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes at Different Levels of Bonus - HGT + Bonus" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 200000 \
bonus_hgt_uptake \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgtbonus_*/data*/\" B_1 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgtbonus_*/data*/\" B_2 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgtbonus_*/data*/\" B_4 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgtbonus_*/data*/\" B_8 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgtbonus_*/data*/\" B_16 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgtbonus_*/data*/\" B_32 

from IPython.display import Image
Image(filename='bonus_hgt_uptake.png')
# Out:
# Aggregating control
# Aggregating B_1
# Aggregating B_2
# Aggregating B_4
# Aggregating B_8
# Aggregating B_16
# Aggregating B_32
#
# Plotting bonus_hgt_uptake

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes at Different Levels of Bonus - Just Bonus" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_bonus_*/data*/\" B_0.1 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_bonus_*/data*/\" B_0.5 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_bonus_*/data*/\" B_1 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_bonus_*/data*/\" B_2 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_bonus_*/data*/\" B_4 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_bonus_*/data*/\" B_8 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_bonus_*/data*/\" B_16 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_bonus_*/data*/\" B_32 

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus.png')
# Out:
# Aggregating control
# Aggregating B_0.1
# Aggregating B_0.5
# Aggregating B_1
# Aggregating B_2
# Aggregating B_4
# Aggregating B_8
# Aggregating B_16
# Aggregating B_32
#
# Plotting bonus_hgt_uptake_bonus

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 1)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_1 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_1_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_1.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_1

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 2)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_2 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_2_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_2.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_2

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 4)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_4 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_4_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_4.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_4

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 8)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_8 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_8_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_8.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_8

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 16)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_16 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_16_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_16.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_16

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 32)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_32 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_32_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_32.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_32

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 0.5)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_0.5 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.5_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_0.5.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_0.5

# %%
# %run ../research_scripts/quickplot.py --error --samples 1000 \
--title "HGT Uptakes with and without Bonus (Bonus: 0.1)" \
--xlabel "Updates" --ylabel "Uptake Events" --xtick_multiplier 100 \
--ylim_max 300000 \
bonus_hgt_uptake_bonus_0.1 \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_control_*/data*/\" control \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_bonus_*/data*/\" NoHGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_hgtbonus_*/data*/\" HGT+Bonus \
hgt.dat 7 \"./raw_data/201_HGT_Bonus_Sweep/Bonus_0.1_hgt_*/data*/\" HGT+NoBonus \

from IPython.display import Image
Image(filename='bonus_hgt_uptake_bonus_0.1.png')
# Out:
# Aggregating control
# Aggregating NoHGT+Bonus
# Aggregating HGT+Bonus
# Aggregating HGT+NoBonus
#
# Plotting bonus_hgt_uptake_bonus_0.1
